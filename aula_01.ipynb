# %% [markdown]
# # Credit Scoring

# %% [markdown]
# ![imagem1.PNG](attachment:imagem1.PNG)

# %% [markdown]
# ![imagem2.PNG](attachment:imagem2.PNG)

# %% [markdown]
# ![Imagem3.PNG](attachment:Imagem3.PNG)

# %% [markdown]
# ![Imagem4.PNG](attachment:Imagem4.PNG)

# %% [markdown]
# ![image.png](attachment:image.png)
